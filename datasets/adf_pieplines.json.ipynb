# %%
{
  "name": "clinical-trials-pipeline",
  "properties": {
    "activities": [
      {
        "name": "Ingest_Trial_Data",
        "type": "Copy",
        "inputs": ["trial_info_source"],
        "outputs": ["bronze_trial_info"]
      },
      {
        "name": "Run_Silver_Transformation",
        "type": "DatabricksNotebook",
        "notebookPath": "/notebooks/02_silver_transformation"
      },
      {
        "name": "Run_Gold_Analytics",
        "type": "DatabricksNotebook",
        "notebookPath": "/notebooks/03_gold_analytics"
      }
    ]
  }
}
